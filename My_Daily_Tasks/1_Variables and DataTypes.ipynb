# %% [markdown]
# # Assignment Instructions
#
# `Hello Innominion,`
#
# - **Try to attempt all the questions in every possible way.**
# - **Some other topics are required to solve some questions. don't panic.**
# - **Those questions can be answered after the topics are taught.**
#
#
# - `Join Mentoring Session for the Support/Doubts Resolving with Our Technical Mentors (2.00 PM - 6.00 PM  Mon-Sat)`
#
# Happy Learning !!!

# %% [markdown]
# ## Basics of Python

# %% [markdown]
# > `Question:` Print your name

# %%
# CODE HERE
print("my name is siddik")
# Out:
# my name is siddik

# %% [markdown]
# > `Question:` What is a variable? Write a Few words about Variables. Create a Variable with an Example.

# %%
# WRITE HERE
 '''A variable in Python is a name that points to a location in memory where data is stored. Variables are used to store values that can be recalled later in the coding process.
variable is used to store the user data temperorly '''

# %%
# Code Here
a= 100
b=0.75
c="string"
print(a)
print(b)
print(c)
# Out:
# 100
# 0.75
# string

# %% [markdown]
# >`Question:` Assume that we execute the following assignment statements:
# width = 17
# height = 12.0
# delimiter = '.'
# For each of the following expressions, write the value of the expression and the type (of the value of
# the expression).
# 1. width/2
# 2. width/2.0
# 3. height/3
# 4. 1 + 2 * 5
# 5. delimiter * 5

# %%
# CODE HERE
width=17
height=12.0
delimiter='.'
print(type(width/2))
print(type(width/2.0))
print(type(height/3))
print(type(1+2*5))
print(type(delimiter*5))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %% [raw]
# # Sample Outputs
# 1. width/2 = 8.5
# 2. width/2.0 = 8.5
# 3. height/3 = 4.0
# 4. 11
# 5. .....

# %% [markdown]
# > `Question:` Add two number by taking variable names as first and seccond

# %%
#CODE HERE

# %%
a=100
b=200
print("first number is : ",a)
print("second number is : ",b)
print("Addition of two numbers are : ",a+b)
# Out:
# first number is :  100
# second number is :  200
# Addition of two numbers are :  300

# %% [markdown]
# > `Question:` Add your first name and second name

# %%
# CODE HERE

# %%
a="Sachin"
b="Tendulkar"
print("My first name is : ",a)
print("My second name is : ",b)
print("My full name is : ",a+" "+b)
# Out:
# My first name is :  Sachin
# My second name is :  Tendulkar
# My full name is :  Sachin Tendulkar

# %% [markdown]
# > `Question:` print the datatypes of the following
# - 10,'10',True,10.5

# %%
# CODE HERE

# %%
print(type(10))
print(type('10'))
print(type(True))
print(type(10.5))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
#  `Question:`
# > - num_int = 123
# > - num_str = "456"
# > - Add num_int and num_str
# - `hint: first need to convert num_str into integer`

# %%
# CODE HERE

# %%
a=123
c='456'
b=int(c)
print("Addition of ",a," and ",c," is: ",a+b)
# Out:
# Addition of  123  and  456  is:  579

# %% [markdown]
# ### Advanced Questions

# %% [markdown]
# > `Question:` The volume of a sphere with radius r is  4/3πr3  . What is the volume of a sphere with radius 5?

# %%
# CODE HERE
import math
r=5
a=(4/3)*(math.pi)*r**3
print(a)
# Out:
# 523.5987755982989

# %% [markdown]
# > `Question:` Suppose the cover price of a book is Rs.24.95, but bookstores get a 40% discount. Shipping costs Rs.3 for the first copy and 75 paise for each additional copy. What is the total wholesale cost for 60 copies?

# %%
# CODE HERE

# %%
b=24.95*(40/100)
c=(b*60)+(59*0.75)+3
print("total wholesale cost for 60 copies is: ",c)
# Out:
# total wholesale cost for 60 copies is:  646.0500000000001

# %% [markdown]
# # [Innomatics Research Labs](https:/innomatics.in/)
# [www.innomatics.in](https:/innomatics.in/)
